# %%
import dask.array as da
import xarray as xr
import numpy as np
import pandas as pd
from dask.distributed import Client
import requests
from pathlib import Path

# %%
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:62594' processes=4 threads=8, memory=16.00 GiB>

# %%
import requests, xarray as xr                                                           
from io import BytesIO                                                                  
                                                                                      
url = (                                                                                 
  "https://coastwatch.pfeg.noaa.gov/erddap/griddap/ncdcOisst21Agg.nc"                 
  "?sst[(1982-01-01T12:00:00Z):1:(2014-12-31T12:00:00Z)]"                             
  "[0:0][(-42.0):1:(-38.0)][(152.0):1:(156.0)]"                                       
)                                                                                       
print("Downloading from ERDDAP (~50 MB)...")                                            
r = requests.get(url, timeout=600)                                                      
r.raise_for_status()                                                                    
print(f"Got {len(r.content)/1e6:.1f} MB")                                               
                                                                                      
with open("examples/oisst_subset.nc", "wb") as f:                                       
  f.write(r.content)                                                                  
                                                                                      
# Quick sanity check                                                                    
ds = xr.open_dataset("examples/oisst_subset.nc")                                        
sst = ds["sst"].squeeze()   # drops the zlev dim                                        
print(sst)                                                                              
print(f"min={float(sst.min()):.2f}  max={float(sst.max()):.2f}")
# Out:
# Downloading from ERDDAP (~50 MB)...
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/miniconda3/envs/mhw3d/lib/python3.10/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/miniconda3/envs/mhw3d/lib/python3.10/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#
# File ~/miniconda3/envs/mhw3d/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1374 try:
# -> 1375     response.begin()
#    1376 except ConnectionError:
#
# File ~/miniconda3/envs/mhw3d/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~/miniconda3/envs/mhw3d/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File ~/miniconda3/envs/mhw3d/lib/python3.10/socket.py:717, in SocketIO.readinto(self, b)
#     716 try:
# --> 717     return self._sock.recv_into(b)
#     718 except timeout:
#
# File ~/miniconda3/envs/mhw3d/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#
# File ~/miniconda3/envs/mhw3d/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1162 if buffer is not None:
# -> 1163     return self._sslobj.read(len, buffer)
#    1164 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/miniconda3/envs/mhw3d/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/miniconda3/envs/mhw3d/lib/python3.10/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/miniconda3/envs/mhw3d/lib/python3.10/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File ~/miniconda3/envs/mhw3d/lib/python3.10/site-packages/urllib3/util/util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File ~/miniconda3/envs/mhw3d/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/miniconda3/envs/mhw3d/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 except (BaseSSLError, OSError) as e:
# --> 536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     537     raise
#
# File ~/miniconda3/envs/mhw3d/lib/python3.10/site-packages/urllib3/connectionpool.py:367, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     366 if isinstance(err, SocketTimeout):
# --> 367     raise ReadTimeoutError(
#     368         self, url, f"Read timed out. (read timeout={timeout_value})"
#     369     ) from err
#     371 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPSConnectionPool(host='coastwatch.pfeg.noaa.gov', port=443): Read timed out. (read timeout=600)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[16], line 10
#       4 url = (
#       5   "https://coastwatch.pfeg.noaa.gov/erddap/griddap/ncdcOisst21Agg.nc"
#       6   "?sst[(1982-01-01T12:00:00Z):1:(2014-12-31T12:00:00Z)]"
#       7   "[0:0][(-42.0):1:(-38.0)][(152.0):1:(156.0)]"
#       8 )
#       9 print("Downloading from ERDDAP (~50 MB)...")
# ---> 10 r = requests.get(url, timeout=600)
#      11 r.raise_for_status()
#      12 print(f"Got {len(r.content)/1e6:.1f} MB")
#
# File ~/miniconda3/envs/mhw3d/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/envs/mhw3d/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/mhw3d/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/mhw3d/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/mhw3d/lib/python3.10/site-packages/requests/adapters.py:713, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     711     raise SSLError(e, request=request)
#     712 elif isinstance(e, ReadTimeoutError):
# --> 713     raise ReadTimeout(e, request=request)
#     714 elif isinstance(e, _InvalidHeader):
#     715     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='coastwatch.pfeg.noaa.gov', port=443): Read timed out. (read timeout=600)

# %%
# Load the saved OISST subset with lazy dask chunks.
# time=-1 keeps the full time axis as a single chunk so _pool_window
# can build the (year, doy) grid without rechunking.
ds_temp = xr.open_dataset("oisst_subset.nc", chunks={"time": -1}).sst
ds_temp
# Out:
# <xarray.DataArray 'sst' (time: 12053, lat: 16, lon: 16)> Size: 12MB
# dask.array<open_dataset-sst, shape=(12053, 16, 16), dtype=float32, chunksize=(12053, 16, 16), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 96kB 1982-01-01 1982-01-02 ... 2014-12-31
#   * lon      (lon) float32 64B 152.1 152.4 152.6 152.9 ... 155.4 155.6 155.9
#   * lat      (lat) float32 64B -41.88 -41.62 -41.38 ... -38.62 -38.38 -38.12
# Attributes:
#     long_name:     Daily Sea Surface Temperature
#     units:         degC
#     valid_range:   [-3. 45.]
#     precision:     2.0
#     dataset:       NOAA High-resolution Blended Analysis
#     var_desc:      Sea Surface Temperature
#     level_desc:    Surface
#     statistic:     Mean
#     parent_stat:   Individual Observations
#     actual_range:  [-1.8  34.48]
#     _ChunkSizes:   [   1  720 1440]

# %%
ds_temp.isel(time=0).plot()

# %%
from mhw3d import common, legacy

# %%
# %%time
# Standard Hobday 2016 baseline period.
clim_period = (1982, 2011)
print("Step 1: Calculating climatology and threshold from baseline period...")
seas   = legacy.compute_climatology(ds_temp, climatologyPeriod=clim_period).compute()
thresh = legacy.compute_threshold(ds_temp,   climatologyPeriod=clim_period).compute()
print(f"  seas shape:   {seas.dims}  {seas.sizes}")
print(f"  thresh shape: {thresh.dims}  {thresh.sizes}")
# Out:
# Step 1: Calculating climatology and threshold from baseline period...
# /Users/neilmalan/Library/CloudStorage/GoogleDrive-neilcmalan@gmail.com/My Drive/CCRC_work/mhw3d-detection/src/mhw3d/legacy/climatology.py:168: RuntimeWarning: Mean of empty slice
#   lambda arr: np.nanmean(arr, axis=0),
# /Users/neilmalan/Library/CloudStorage/GoogleDrive-neilcmalan@gmail.com/My Drive/CCRC_work/mhw3d-detection/src/mhw3d/legacy/climatology.py:168: RuntimeWarning: Mean of empty slice
#   lambda arr: np.nanmean(arr, axis=0),
# /Users/neilmalan/Library/CloudStorage/GoogleDrive-neilcmalan@gmail.com/My Drive/CCRC_work/mhw3d-detection/src/mhw3d/legacy/climatology.py:168: RuntimeWarning: Mean of empty slice
#   lambda arr: np.nanmean(arr, axis=0),
# /Users/neilmalan/Library/CloudStorage/GoogleDrive-neilcmalan@gmail.com/My Drive/CCRC_work/mhw3d-detection/src/mhw3d/legacy/climatology.py:168: RuntimeWarning: Mean of empty slice
#   lambda arr: np.nanmean(arr, axis=0),
# /Users/neilmalan/Library/CloudStorage/GoogleDrive-neilcmalan@gmail.com/My Drive/CCRC_work/mhw3d-detection/src/mhw3d/legacy/climatology.py:168: RuntimeWarning: Mean of empty slice
#   lambda arr: np.nanmean(arr, axis=0),
# /Users/neilmalan/Library/CloudStorage/GoogleDrive-neilcmalan@gmail.com/My Drive/CCRC_work/mhw3d-detection/src/mhw3d/legacy/climatology.py:168: RuntimeWarning: Mean of empty slice
#   lambda arr: np.nanmean(arr, axis=0),
# /Users/neilmalan/Library/CloudStorage/GoogleDrive-neilcmalan@gmail.com/My Drive/CCRC_work/mhw3d-detection/src/mhw3d/legacy/climatology.py:168: RuntimeWarning: Mean of empty slice
#   lambda arr: np.nanmean(arr, axis=0),
# /Users/neilmalan/Library/CloudStorage/GoogleDrive-neilcmalan@gmail.com/My Drive/CCRC_work/mhw3d-detection/src/mhw3d/legacy/climatology.py:168: RuntimeWarning: Mean of empty slice
#   lambda arr: np.nanmean(arr, axis=0),
# /Users/neilmalan/Library/CloudStorage/GoogleDrive-neilcmalan@gmail.com/My Drive/CCRC_work/mhw3d-detection/src/mhw3d/legacy/climatology.py:168: RuntimeWarning: Mean of empty slice
#   lambda arr: np.nanmean(arr, axis=0),
# /Users/neilmalan/miniconda3/envs/mhw3d/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1601: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# /Users/neilmalan/miniconda3/envs/mhw3d/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1601: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
#   seas shape:   ('lat', 'lon', 'dayofyear')  Frozen({'lat': 16, 'lon': 16, 'dayofyear': 366})
#   thresh shape: ('lat', 'lon', 'dayofyear')  Frozen({'lat': 16, 'lon': 16, 'dayofyear': 366})
# CPU times: user 550 ms, sys: 71.5 ms, total: 621 ms
# Wall time: 5.9 s

# %%
# %%time
print("Step 2: Computing T_anom and severity over the full record...")
severity_ds = common.calculate_severity(ds_temp, seas, thresh)
print(f"  T_anom shape:   {severity_ds['T_anom'].dims}")
print(f"  severity shape: {severity_ds['severity'].dims}")
# Out:
# Step 2: Computing T_anom and severity over the full record...
#   T_anom shape:   ('time', 'lat', 'lon')
#   severity shape: ('time', 'lat', 'lon')
# CPU times: user 32.9 ms, sys: 7.84 ms, total: 40.7 ms
# Wall time: 39 ms

# %%
# %%time
print("Step 3: Rechunking for detection (time must be a single chunk)...")
severity_ds = severity_ds.chunk({"time": -1, "lat": "auto", "lon": "auto"})

print("Step 4: Detecting MHW events (lazy graph build)...")
mhw_lazy = common.calculate_mhw_metrics(severity_ds)

print("Step 5: Computing (main workload)...")
mhw = mhw_lazy.compute()
print("Done.")
# Out:
# Step 3: Rechunking for detection (time must be a single chunk)...
# Step 4: Detecting MHW events (lazy graph build)...
# Step 5: Computing (main workload)...
# /Users/neilmalan/miniconda3/envs/mhw3d/lib/python3.10/site-packages/distributed/client.py:3371: UserWarning: Sending large graph of size 11.88 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# Done.
# CPU times: user 33.8 ms, sys: 28.7 ms, total: 62.5 ms
# Wall time: 308 ms

# %%
# Trim empty event slots and check the results
mhw_trimmed = mhw.dropna("event", how="all")
n_events_per_cell = (~mhw["date_start"].isnull()).sum("event")

print(f"Output shape: {dict(mhw.dims)}")
print(f"Grid cells with ≥1 event: {int((n_events_per_cell > 0).sum().values)}")
print(f"Max events in any cell: {int(n_events_per_cell.max().values)}")
display(mhw_trimmed)
# Out:
# Output shape: {'lat': 16, 'lon': 16, 'event': 200}
# Grid cells with ≥1 event: 0
# Max events in any cell: 0
# /var/folders/g0/w24709ld71b5r2ln5v1rzt6c0000gq/T/ipykernel_29537/2533979664.py:5: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   print(f"Output shape: {dict(mhw.dims)}")
# <xarray.Dataset> Size: 128B
# Dimensions:          (lat: 16, lon: 16, event: 0)
# Coordinates:
#   * lon              (lon) float32 64B 152.1 152.4 152.6 ... 155.4 155.6 155.9
#   * lat              (lat) float32 64B -41.88 -41.62 -41.38 ... -38.38 -38.12
# Dimensions without coordinates: event
# Data variables:
#     index_start      (lat, lon, event) float64 0B
#     index_end        (lat, lon, event) float64 0B
#     date_start       (lat, lon, event) datetime64[ns] 0B
#     date_end         (lat, lon, event) datetime64[ns] 0B
#     duration         (lat, lon, event) float64 0B
#     index_peak       (lat, lon, event) float64 0B
#     date_peak        (lat, lon, event) datetime64[ns] 0B
#     intensity_max    (lat, lon, event) float64 0B
#     intensity_mean   (lat, lon, event) float64 0B
#     intensity_cumul  (lat, lon, event) float64 0B

# %% [markdown]
# ---
# ## 2D correctness check — time × latitude transect
#
# Verify the pipeline works on a 2D array (time × lat), as you'd get from a mooring array or a single longitude slice. Uses `legacy` for a known reference output.

# %%
from mhw3d import legacy

np.random.seed(42)
time_2d = pd.date_range("1982-01-01", "2013-12-31", freq="D")
n_lat = 20
t = np.arange(len(time_2d), dtype=float)

base = 15.0 + np.linspace(0, 5, n_lat)
seas_signal = 5.0 * np.cos(2 * np.pi * t[:, None] / 365.25)
noise = 0.5 * np.random.randn(len(time_2d), n_lat)
data_2d = base[None, :] + seas_signal + noise
data_2d[1000:1050, 5:10] += 4.0

da_2d = xr.DataArray(
    data_2d,
    dims=["time", "lat"],
    coords={"time": time_2d, "lat": np.arange(n_lat)},
    name="sst"
)
print(f"2D DataArray: {da_2d.dims}  {dict(da_2d.sizes)}")

seas_2d   = legacy.compute_climatology(da_2d, climatologyPeriod=(1982, 2011))
thresh_2d = legacy.compute_threshold(da_2d,   climatologyPeriod=(1982, 2011))
sev_2d    = common.calculate_severity(da_2d, seas_2d, thresh_2d)

# Time must be a single chunk before detection
sev_2d    = sev_2d.chunk({"time": -1})
mhw_2d    = common.calculate_mhw_metrics(sev_2d)

mhw_2d_trimmed = mhw_2d.dropna("event", how="all")
n_events_2d = (~mhw_2d["date_start"].isnull()).sum("event")

print(f"Output shape: {dict(mhw_2d.dims)}")
print(f"Events per latitude:\n{n_events_2d.values}")
assert int(n_events_2d.sel(lat=7).values) >= 1, "Expected ≥1 event in the seeded lat band"
print("✓ Events detected in seeded latitude band")
display(mhw_2d_trimmed)

# %% [markdown]
# ---
# ## 1D correctness check — single mooring point
#
# Verify the pipeline works on a plain 1D time series (no spatial dimensions), as you'd get from a single CTD or Argo float record.

# %%
np.random.seed(7)
time_1d = pd.date_range("1982-01-01", "2013-12-31", freq="D")
t = np.arange(len(time_1d), dtype=float)

data_1d = (
    15.0
    + 5.0 * np.cos(2 * np.pi * t / 365.25)
    + 0.5 * np.random.randn(len(time_1d))
)
data_1d[4000:4100] += 3.5

da_1d = xr.DataArray(
    data_1d,
    dims=["time"],
    coords={"time": time_1d},
    name="sst"
)
print(f"1D DataArray: {da_1d.dims}  {dict(da_1d.sizes)}")

# expand_dims so calculate_mhw_metrics has at least one spatial dimension to vectorise over
da_1d_3d = da_1d.expand_dims(["lat", "lon"])

seas_1d   = legacy.compute_climatology(da_1d_3d, climatologyPeriod=(1982, 2011))
thresh_1d = legacy.compute_threshold(da_1d_3d,   climatologyPeriod=(1982, 2011))
sev_1d    = common.calculate_severity(da_1d_3d, seas_1d, thresh_1d)

# Time must be a single chunk before detection
sev_1d    = sev_1d.chunk({"time": -1})
mhw_1d    = common.calculate_mhw_metrics(sev_1d).squeeze(drop=True)
mhw_1d_trimmed = mhw_1d.dropna("event", how="all")

n_events_1d = mhw_1d_trimmed.sizes["event"]
print(f"Events detected: {n_events_1d}")
assert n_events_1d >= 1, "Expected ≥1 event in the seeded 1D series"
print("✓ At least one event detected")
display(mhw_1d_trimmed[["date_start", "date_end", "date_peak", "duration", "intensity_max"]])
